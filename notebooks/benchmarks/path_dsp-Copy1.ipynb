# %%
# !pip install openpyxl
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
#
# [notice] A new release of pip is available: 23.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# ALWAYS RUN THIS FIRST!
import os
import sys
from pathlib import Path

NOTEBOOK_DIR = Path("/rsrch9/home/plm/idso_fa1_pathology/codes/yshokrollahi/vitamin-p-latest")
os.chdir(NOTEBOOK_DIR)
sys.path.insert(0, str(NOTEBOOK_DIR))

print(f"✅ Working directory: {os.getcwd()}")
# Out:
# ✅ Working directory: /rsrch9/home/plm/idso_fa1_pathology/codes/yshokrollahi/vitamin-p-latest

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from collections import Counter

# Base path
base_path = '/rsrch9/home/plm/idso_fa1_pathology/TIER1/patient-mosaic/2014-0938/MOSAIC/DSP'

# Dictionary to store all data
all_data = {}

# Iterate through Set 1 to Set 16
for i in range(1, 17):
    # Try both naming conventions
    folder_names = [f'MOSAIC DSP Set {i}', f'MOSAIC Set {i}']
    file_names = [f'MOSAIC DSP Set {i} Annotations AS.xlsx', f'MOSAIC Set {i} Annotations AS.xlsx']
    
    found = False
    for folder_name in folder_names:
        for file_name in file_names:
            file_path = os.path.join(base_path, folder_name, 'Data', file_name)
            
            # Check if file exists
            if os.path.exists(file_path):
                found = True
                print(f"\n{'='*60}")
                print(f"SET {i}")
                print(f"{'='*60}")
                
                try:
                    # Read the Excel file to check column names
                    df = pd.read_excel(file_path)
                    
                    # Determine which column name is present
                    if 'Primary_Dx' in df.columns:
                        dx_column = 'Primary_Dx'
                    elif 'Primary Dx' in df.columns:
                        dx_column = 'Primary Dx'
                    else:
                        print(f"Neither 'Primary_Dx' nor 'Primary Dx' found in columns")
                        print(f"Available columns: {list(df.columns)}")
                        break
                    
                    # Keep only the columns we need
                    df = df[['Slide_ID_DSP', dx_column]]
                    
                    # Remove duplicate slide IDs
                    df_unique = df.drop_duplicates(subset='Slide_ID_DSP')
                    
                    # Print and store the results
                    for _, row in df_unique.iterrows():
                        slide_id = row['Slide_ID_DSP']
                        cancer_type = row[dx_column]
                        print(f"{slide_id} has {cancer_type}")
                        
                        # Store in dictionary (skip control samples)
                        if 'control' not in cancer_type.lower() and 'tonsil' not in cancer_type.lower():
                            all_data[slide_id] = cancer_type
                            
                except Exception as e:
                    print(f"Error reading file: {e}")
                
                break
        if found:
            break
    
    if not found:
        print(f"\n{'='*60}")
        print(f"SET {i}")
        print(f"{'='*60}")
        print(f"File not found for Set {i}")

print(f"\n{'='*60}")
print("VISUALIZATION")
print(f"{'='*60}")

# Count cancer types
cancer_counts = Counter(all_data.values())

# Sort by frequency
sorted_cancers = sorted(cancer_counts.items(), key=lambda x: x[1], reverse=True)
cancer_types = [x[0] for x in sorted_cancers]
counts = [x[1] for x in sorted_cancers]

# Create figure
fig, ax = plt.subplots(figsize=(10, 14))

# Create horizontal bar chart
bars = ax.barh(cancer_types, counts, color='#2E86AB', edgecolor='black', linewidth=0.5)

# Styling for Nature-style
ax.set_xlabel('Number of Cases', fontsize=12, fontweight='bold')
ax.set_ylabel('Cancer Type', fontsize=12, fontweight='bold')
ax.set_title(f'Distribution of Rare Cancer Types (n={len(all_data)} cases)', fontsize=14, fontweight='bold', pad=20)

# Add count labels on bars
for i, (bar, count) in enumerate(zip(bars, counts)):
    ax.text(count + 0.3, i, str(count), va='center', fontsize=10)

# Clean up
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.grid(axis='x', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# Print summary statistics
print(f"\nTotal cases: {len(all_data)}")
print(f"Distinct cancer types: {len(cancer_counts)}")
print(f"\nCancer type frequencies:")
for cancer, count in sorted_cancers:
    print(f"{cancer}: {count}")
# Out:
# ============================================================
# SET 1
# ============================================================
# MOS001S1 has Ovarian clear cell carcinoma
# MOS002S1 has Cholangiocarcinoma
# MOS003S1 has Colorectal adenocarcinoma
# MOS004S1 has Rectal squamous cell carcinoma
# MOS005S1 has Cholangiocarcinoma
# MOS006S1 has Cholangiocarcinoma
# MOS007S1 has Cholangiocarcinoma
# MOS008S1 has Hurthle cell carcinoma
# MOS009S1 has Cholangiocarcinoma
# MOS010S1 has Lung adenocarcinoma
# MOS011S1 has Papillary thyroid carcinoma
# MOS012S1 has Colorectal adenocarcinoma
# MOS014S1 has Ovarian serous carcinoma
# TO20S1 has Control tonsil
#
# ============================================================
# SET 2
# ============================================================
# MOS015S1 has Papillary urothelial carcinoma
# MOS016S1 has Papillary urothelial carcinoma
# MOS017S1 has Papillary urothelial carcinoma
# MOS018S1 has Papillary urothelial carcinoma
# MOS019S1 has Papillary urothelial carcinoma
# MOS020S1 has Papillary urothelial carcinoma
# MOS021S1 has Papillary urothelial carcinoma
# MOS022S1 has Papillary urothelial carcinoma
# MOS023S1 has Papillary urothelial carcinoma
# MOS024S1 has Papillary urothelial carcinoma
# MOS025S1 has Papillary urothelial carcinoma
# MOS026S1 has Papillary urothelial carcinoma
# MOS027S1 has Urothelial carcinoma
# MOS028S1 has Papillary urothelial carcinoma
# MOS029S1 has Papillary urothelial carcinoma
#
# ============================================================
# SET 3
# ============================================================
# MOS030S1 has Appendiceal adenocarcinoma
# MOS031S1 has Rectal squamous cell carcinoma
# MOS032S1 has Cholangiocarcinoma
# MOS033S1 has Mucoepidermoid carcinoma
# MOS034S1 has Penile squamous cell carcinoma
# MOS035S1 has Papillary urothelial carcinoma
# MOS036S1 has Penile squamous cell carcinoma
# MOS037S1 has Papillary urothelial carcinoma
# MOS038S1 has Papillary urothelial carcinoma
# MOS039S1 has Papillary urothelial carcinoma
# MOS040S1 has Papillary urothelial carcinoma
# MOS041S1 has Urothelial carcinoma
# MOS042S1 has Renal cell  carcinoma
# MOS043S1 has Papillary urothelial carcinoma
# MOS044S1 has Papillary urothelial carcinoma
# TO20S1 has Control tonsil
#
# ============================================================
# SET 4
# ============================================================
# MOS045S1 has Medullary thyroid carcinoma
# MOS046S1 has Pancreatic neuroendocrine tumor
# MOS047S1 has Lung neuroendocrine carcinoma
# MOS048T2S1 has Cervical neuroendocrine carcinoma
# MOS049T2S1 has Neuroendocrine carcinoma
# MOS050T2S1 has Pancreatic neuroendocrine tumor
# MOS051T2S1 has Pancreatic neuroendocrine tumor
# MOS052T2S1 has Merkel cell carcinoma
# MOS053T2S1 has Neuroendocrine tumor
# MOS054T2S1 has Neuroendocrine tumor
# TO20S1 has Control tonsil
#
# ============================================================
# SET 5
# ============================================================
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# MOS055S1 has Mesothelioma
# MOS056S1 has Mesothelioma
# MOS057S1 has Mesothelioma
# MOS058S1 has Hepatocellular carcinoma
# MOS059S1 has Ovarian clear cell carcinoma
# MOS060S1 has Well-differentiated papillary mesothelial tumor
# MOS061S1 has  Pancreas solid pseudopapillary neoplasm
# MOS062S1 has Colorectal adenocarcinoma
# MOS063S1 has Mucoepidermoid carcinoma
# MOS064S1 has Esophageal adenocarcinoma
# MOS065S1 has Esophageal adenocarcinoma
# MOS066S1 has Papillary urothelial carcinoma
# MOS067S1 has Undifferentiated thyroid carcinoma
# MOS068S1 has Papillary urothelial carcinoma
# MOS069S1 has Papillary urothelial carcinoma
#
# ============================================================
# SET 6
# ============================================================
# MOS070S1 has Anorectal melanoma
# MOS071S1 has Anorectal melanoma
# MOS072S1 has Anorectal melanoma
# MOS073S1 has Uveal Melanoma
# MOS074S1 has Uveal Melanoma
# MOS075S1 has Uveal Melanoma
# MOS076S1 has Cutaneous Melanoma
#
# ============================================================
# SET 7
# ============================================================
# MOS077S1 has Colorectal adenocarcinoma
# MOS078S1 has Invasive thymoma
# MOS079S1 has Papillary urothelial carcinoma
# MOS080S1 has Colorectal adenocarcinoma
#
# ============================================================
# SET 8
# ============================================================
# MOS081S1 has Neuroendocrine tumor
#
# ============================================================
# SET 9
# ============================================================
# MOS082S1 has Spindle cell neoplasm
# MOS083S1 has Malignant sarcomatoid tumor
# MOS084S1 has Uterine adenosarcoma
# MOS085S1 has Spindle cell malignant neoplasm
# MOS086S1 has Chondrosarcoma
# MOS087S1 has Dedifferentiated liposarcoma
# MOS087S3 has Dedifferentiated liposarcoma
# MOS088S1 has Unclassified small round cell sarcoma
# MOS089S1 has Dedifferentiated liposarcoma
# MOS089S3 has Dedifferentiated liposarcoma
# MOS090S1 has Spindle Cell Sarcoma
# MOS091T2S1 has Dedifferentiated liposarcoma
# MOS092S4 has Dermatofibrosarcoma
# MOS093S4 has Osteosarcoma
# MOS094T2S1 has Pleomorphic sarcoma
# MOS095S3 has Dedifferentiated liposarcoma
# MOS096S3 has Undifferentiated pleomorphic sarcoma
# MOS096S4 has Undifferentiated pleomorphic sarcoma
# TO20S2 has Control tonsil
#
# ============================================================
# SET 10
# ============================================================
# MOS097S1 has Synovial Sarcoma
# MOS098S1 has Leiomyosarcoma
# MOS099S1 has Ossifying fibromyxoid tumor
# MOS100S1 has Desmoplastic small round cell tumor
# MOS100S3 has Desmoplastic small round cell tumor
# MOS101S1 has Leiomyosarcoma
# MOS101S3 has Leiomyosarcoma
# MOS102S1 has Leiomyosarcoma
# MOS103S1 has Liposarcoma
# MOS104S1 has Hyalinizing spindle cell sarcoma
# MOS105S1 has Synovial Sarcoma
# MOS106S1 has Leiomyosarcoma
# MOS107S1 has Undifferentiated pleomorphic sarcoma
# MOS108S1 has Spindle cell malignant neoplasm
# MOS109S1 has Well-differentiated liposarcoma
# MOS110S1 has Pleomorphic sarcoma
# MOS111S1 has Dedifferentiated liposarcoma
# MOS111S2 has Dedifferentiated liposarcoma
# MOS112S1 has Well-differentiated liposarcoma
#
# ============================================================
# SET 11
# ============================================================
# MOS113S1 has Dedifferentiated liposarcoma
# MOS114S1 has Rhabdomyosarcoma
# MOS115S1 has Chondrosarcoma
# MOS116S1 has Well-differentiated liposarcoma
# MOS117S1 has Liposarcoma
# MOS118S1 has Alveolar soft part sarcoma
# MOS119S1 has Leiomyosarcoma
# MOS120S1 has Leiomyosarcoma
# MOS121S1 has Chondrosarcoma
# MOS122S1 has Leiomyosarcoma
# MOS123S1 has Synovial Sarcoma
# MOS124S1 has Undifferentiated pleomorphic sarcoma
# MOS125S1 has Undifferentiated pleomorphic sarcoma
# MOS126T2S1 has Synovial Sarcoma
# MOS127S1 has Dedifferentiated liposarcoma
# MOS128S1 has Synovial Sarcoma
#
# ============================================================
# SET 12
# ============================================================
# MOS129S1 has Well-differentiated liposarcoma
# MOS130S1 has Chondrosarcoma
# MOS131S1 has Well-differentiated liposarcoma
# MOS132S1 has Spindle cell sarcoma
# MOS133S1 has Liposarcoma
# MOS134S1 has Liposarcoma
# MOS135S1 has Chondrosarcoma
# MOS136S1 has Chondrosarcoma
# MOS137S1 has Undifferentiated pleomorphic sarcoma
# MOS138T2S1 has Low grade sarcomatoid process
# MOS139S1 has Spindle cell sarcoma
# MOS140S1 has Leiomyosarcoma
# MOS141S1 has Leiomyosarcoma
# MOS142S1 has Leiomyosarcoma
# MOS143S1 has Synovial sarcoma
# MOS144S1 has Synovial sarcoma
# TO20S1 has Control tonsil
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# /home/yshokrollahi/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# ============================================================
# SET 13
# ============================================================
# MOS145S1 has Leiomyosarcoma
# MOS146S1 has Well-differentiated liposarcoma
# MOS147S1 has Liposarcoma
# MOS148S1 has Liposarcoma
# MOS149S1 has Well-differentiated liposarcoma
# MOS150S1 has Extraskeletal Chondrosarcoma
# MOS151S1 has Synovial Sarcoma
# MOS152S1 has Spindle cell neoplasm
# MOS153S1 has Uterine carcinosarcoma
# MOS154S1 has Uterine adenosarcoma
# MOS155S1 has Chondrosarcoma
# MOS156S1 has Chondrosarcoma
# MOS157S1 has Leiomyosarcoma
# MOS158S1 has Chordoma
# MOS159T2S1 has Leiomyosarcoma
#
# ============================================================
# SET 14
# ============================================================
# MOS160S1 has Vulvovaginal melanoma
# MOS161S1 has Vulvovaginal melanoma
# MOS162S1 has Vulvovaginal melanoma
# MOS163S1 has Sinonasal melanoma
# MOS165S1 has Sinonasal melanoma
# MOS166S1 has Vulvovaginal melanoma
# MOS167S1 has Sinonasal melanoma
# MOS168S1 has Anorectal melanoma
# MOS169S1 has Anorectal melanoma
# MOS170S1 has Anorectal melanoma
# MOS171S1 has Conjunctival melanoma
# MOS172S1 has Anorectal melanoma
# MOS173S1 has Anorectal melanoma
# MOS174S1 has Anorectal melanoma
# MOS175S1 has Anorectal melanoma
# MOS176S1 has Vulvovaginal melanoma
# TO20S1 has Control tonsil
#
# ============================================================
# SET 15
# ============================================================
# MOS177S1 has Sinonasal melanoma
# MOS178S1 has Anorectal melanoma
# MOS179S1 has Sinonasal melanoma
# MOS180S1 has Sinonasal melanoma
# MOS181S1 has Vulvovaginal melanoma
# MOS182S1 has Vulvovaginal melanoma
# MOS183S3 has Anorectal melanoma
# MOS184S1 has Nasolacrimal melanoma
# MOS185S1 has Anorectal melanoma
# MOS186S2 has Anorectal melanoma
# MOS187S2 has Sinonasal melanoma
# MOS188S1 has Anorectal melanoma
# MOS189S1 has Sinonasal melanoma
# MOS190S1 has Vulvovaginal melanoma
#
# ============================================================
# SET 16
# ============================================================
# File not found for Set 16
#
# ============================================================
# VISUALIZATION
# ============================================================
# Total cases: 194
# Distinct cancer types: 63
#
# Cancer type frequencies:
# Papillary urothelial carcinoma: 25
# Anorectal melanoma: 15
# Leiomyosarcoma: 14
# Dedifferentiated liposarcoma: 10
# Chondrosarcoma: 8
# Vulvovaginal melanoma: 8
# Sinonasal melanoma: 8
# Well-differentiated liposarcoma: 7
# Cholangiocarcinoma: 6
# Undifferentiated pleomorphic sarcoma: 6
# Synovial Sarcoma: 6
# Liposarcoma: 6
# Colorectal adenocarcinoma: 5
# Pancreatic neuroendocrine tumor: 3
# Neuroendocrine tumor: 3
# Mesothelioma: 3
# Uveal Melanoma: 3
# Rectal squamous cell carcinoma: 2
# Urothelial carcinoma: 2
# Mucoepidermoid carcinoma: 2
# Penile squamous cell carcinoma: 2
# Esophageal adenocarcinoma: 2
# Spindle cell neoplasm: 2
# Uterine adenosarcoma: 2
# Spindle cell malignant neoplasm: 2
# Pleomorphic sarcoma: 2
# Desmoplastic small round cell tumor: 2
# Spindle cell sarcoma: 2
# Synovial sarcoma: 2
# Ovarian clear cell carcinoma : 1
# Hurthle cell carcinoma: 1
# Lung adenocarcinoma: 1
# Papillary thyroid carcinoma: 1
# Ovarian serous carcinoma: 1
# Appendiceal adenocarcinoma: 1
# Renal cell  carcinoma: 1
# Medullary thyroid carcinoma: 1
# Lung neuroendocrine carcinoma: 1
# Cervical neuroendocrine carcinoma: 1
# Neuroendocrine carcinoma: 1
# Merkel cell carcinoma: 1
# Hepatocellular carcinoma: 1
# Ovarian clear cell carcinoma: 1
# Well-differentiated papillary mesothelial tumor: 1
#  Pancreas solid pseudopapillary neoplasm: 1
# Undifferentiated thyroid carcinoma: 1
# Cutaneous Melanoma: 1
# Invasive thymoma: 1
# Malignant sarcomatoid tumor: 1
# Unclassified small round cell sarcoma: 1
# Spindle Cell Sarcoma: 1
# Dermatofibrosarcoma: 1
# Osteosarcoma: 1
# Ossifying fibromyxoid tumor: 1
# Hyalinizing spindle cell sarcoma: 1
# Rhabdomyosarcoma: 1
# Alveolar soft part sarcoma: 1
# Low grade sarcomatoid process: 1
# Extraskeletal Chondrosarcoma: 1
# Uterine carcinosarcoma: 1
# Chordoma: 1
# Conjunctival melanoma: 1
# Nasolacrimal melanoma: 1

# %%
import pandas as pd
from collections import Counter, defaultdict

# Your data (extracted from the output)
all_data = {
    'MOS001S1': 'Ovarian clear cell carcinoma ',
    'MOS002S1': 'Cholangiocarcinoma',
    'MOS003S1': 'Colorectal adenocarcinoma',
    'MOS004S1': 'Rectal squamous cell carcinoma',
    'MOS008S1': 'Hurthle cell carcinoma',
    'MOS010S1': 'Lung adenocarcinoma',
    'MOS011S1': 'Papillary thyroid carcinoma',
    'MOS014S1': 'Ovarian serous carcinoma',
    'MOS015S1': 'Papillary urothelial carcinoma',
    'MOS027S1': 'Urothelial carcinoma',
    'MOS030S1': 'Appendiceal adenocarcinoma',
    'MOS033S1': 'Mucoepidermoid carcinoma',
    'MOS034S1': 'Penile squamous cell carcinoma',
    'MOS042S1': 'Renal cell  carcinoma',
    'MOS045S1': 'Medullary thyroid carcinoma',
    'MOS046S1': 'Pancreatic neuroendocrine tumor',
    'MOS047S1': 'Lung neuroendocrine carcinoma',
    'MOS048T2S1': 'Cervical neuroendocrine carcinoma',
    'MOS049T2S1': 'Neuroendocrine carcinoma',
    'MOS052T2S1': 'Merkel cell carcinoma',
    'MOS053T2S1': 'Neuroendocrine tumor',
    'MOS055S1': 'Mesothelioma',
    'MOS058S1': 'Hepatocellular carcinoma',
    'MOS059S1': 'Ovarian clear cell carcinoma',
    'MOS060S1': 'Well-differentiated papillary mesothelial tumor',
    'MOS061S1': ' Pancreas solid pseudopapillary neoplasm',
    'MOS064S1': 'Esophageal adenocarcinoma',
    'MOS067S1': 'Undifferentiated thyroid carcinoma',
    'MOS070S1': 'Anorectal melanoma',
    'MOS073S1': 'Uveal Melanoma',
    'MOS076S1': 'Cutaneous Melanoma',
    'MOS078S1': 'Invasive thymoma',
    'MOS082S1': 'Spindle cell neoplasm',
    'MOS083S1': 'Malignant sarcomatoid tumor',
    'MOS084S1': 'Uterine adenosarcoma',
    'MOS085S1': 'Spindle cell malignant neoplasm',
    'MOS086S1': 'Chondrosarcoma',
    'MOS087S1': 'Dedifferentiated liposarcoma',
    'MOS088S1': 'Unclassified small round cell sarcoma',
    'MOS090S1': 'Spindle Cell Sarcoma',
    'MOS092S4': 'Dermatofibrosarcoma',
    'MOS093S4': 'Osteosarcoma',
    'MOS094T2S1': 'Pleomorphic sarcoma',
    'MOS096S3': 'Undifferentiated pleomorphic sarcoma',
    'MOS097S1': 'Synovial Sarcoma',
    'MOS098S1': 'Leiomyosarcoma',
    'MOS099S1': 'Ossifying fibromyxoid tumor',
    'MOS100S1': 'Desmoplastic small round cell tumor',
    'MOS103S1': 'Liposarcoma',
    'MOS104S1': 'Hyalinizing spindle cell sarcoma',
    'MOS109S1': 'Well-differentiated liposarcoma',
    'MOS114S1': 'Rhabdomyosarcoma',
    'MOS118S1': 'Alveolar soft part sarcoma',
    'MOS132S1': 'Spindle cell sarcoma',
    'MOS138T2S1': 'Low grade sarcomatoid process',
    'MOS143S1': 'Synovial sarcoma',
    'MOS150S1': 'Extraskeletal Chondrosarcoma',
    'MOS153S1': 'Uterine carcinosarcoma',
    'MOS158S1': 'Chordoma',
    'MOS160S1': 'Vulvovaginal melanoma',
    'MOS163S1': 'Sinonasal melanoma',
    'MOS171S1': 'Conjunctival melanoma',
    'MOS184S1': 'Nasolacrimal melanoma',
}

# Group by cancer type
cancer_to_slides = defaultdict(list)
for slide, cancer in all_data.items():
    cancer_to_slides[cancer].append(slide)

# Print selected samples
print("SELECTED SAMPLES TO REPRESENT ALL 63 DISTINCT CANCER TYPES")
print("="*70)
print(f"\nTotal samples needed: {len(cancer_to_slides)}")
print(f"\nSlide ID -> Cancer Type")
print("-"*70)

selected_samples = []
for cancer_type in sorted(cancer_to_slides.keys()):
    # Select the first slide for each cancer type
    slide_id = cancer_to_slides[cancer_type][0]
    selected_samples.append((slide_id, cancer_type))
    print(f"{slide_id:15s} -> {cancer_type}")

print("\n" + "="*70)
print(f"TOTAL SELECTED: {len(selected_samples)} samples")
print("="*70)

# Print by cancer category for better organization
print("\n\nORGANIZED BY CATEGORY:")
print("="*70)

categories = {
    'Carcinomas - GI': ['Cholangiocarcinoma', 'Colorectal adenocarcinoma', 'Rectal squamous cell carcinoma', 
                        'Appendiceal adenocarcinoma', 'Esophageal adenocarcinoma', 'Hepatocellular carcinoma',
                        ' Pancreas solid pseudopapillary neoplasm'],
    'Carcinomas - Gynecologic': ['Ovarian clear cell carcinoma ', 'Ovarian clear cell carcinoma', 'Ovarian serous carcinoma',
                                  'Cervical neuroendocrine carcinoma', 'Uterine adenosarcoma', 'Uterine carcinosarcoma'],
    'Carcinomas - Urologic': ['Papillary urothelial carcinoma', 'Urothelial carcinoma', 'Renal cell  carcinoma',
                              'Penile squamous cell carcinoma'],
    'Carcinomas - Thyroid': ['Papillary thyroid carcinoma', 'Medullary thyroid carcinoma', 'Undifferentiated thyroid carcinoma',
                            'Hurthle cell carcinoma'],
    'Neuroendocrine Tumors': ['Pancreatic neuroendocrine tumor', 'Lung neuroendocrine carcinoma', 'Neuroendocrine carcinoma',
                              'Neuroendocrine tumor', 'Merkel cell carcinoma'],
    'Lung': ['Lung adenocarcinoma'],
    'Mesothelioma': ['Mesothelioma', 'Well-differentiated papillary mesothelial tumor'],
    'Other Carcinomas': ['Mucoepidermoid carcinoma', 'Invasive thymoma'],
    'Melanomas': ['Anorectal melanoma', 'Vulvovaginal melanoma', 'Sinonasal melanoma', 'Uveal Melanoma',
                  'Cutaneous Melanoma', 'Conjunctival melanoma', 'Nasolacrimal melanoma'],
    'Sarcomas - Liposarcoma': ['Dedifferentiated liposarcoma', 'Well-differentiated liposarcoma', 'Liposarcoma'],
    'Sarcomas - Leiomyosarcoma': ['Leiomyosarcoma'],
    'Sarcomas - Bone/Cartilage': ['Chondrosarcoma', 'Osteosarcoma', 'Extraskeletal Chondrosarcoma', 'Chordoma'],
    'Sarcomas - Synovial': ['Synovial Sarcoma', 'Synovial sarcoma'],
    'Sarcomas - Pleomorphic/Spindle': ['Undifferentiated pleomorphic sarcoma', 'Pleomorphic sarcoma', 'Spindle cell neoplasm',
                                        'Spindle cell malignant neoplasm', 'Spindle Cell Sarcoma', 'Spindle cell sarcoma'],
    'Sarcomas - Other': ['Malignant sarcomatoid tumor', 'Unclassified small round cell sarcoma', 'Dermatofibrosarcoma',
                         'Desmoplastic small round cell tumor', 'Ossifying fibromyxoid tumor', 'Hyalinizing spindle cell sarcoma',
                         'Rhabdomyosarcoma', 'Alveolar soft part sarcoma', 'Low grade sarcomatoid process']
}

for category, cancer_types in categories.items():
    print(f"\n{category}:")
    for cancer_type in cancer_types:
        if cancer_type in cancer_to_slides:
            slide_id = cancer_to_slides[cancer_type][0]
            print(f"  {slide_id:15s} -> {cancer_type}")
# Out:
# SELECTED SAMPLES TO REPRESENT ALL 63 DISTINCT CANCER TYPES
# ======================================================================
#
# Total samples needed: 63
#
# Slide ID -> Cancer Type
# ----------------------------------------------------------------------
# MOS061S1        ->  Pancreas solid pseudopapillary neoplasm
# MOS118S1        -> Alveolar soft part sarcoma
# MOS070S1        -> Anorectal melanoma
# MOS030S1        -> Appendiceal adenocarcinoma
# MOS048T2S1      -> Cervical neuroendocrine carcinoma
# MOS002S1        -> Cholangiocarcinoma
# MOS086S1        -> Chondrosarcoma
# MOS158S1        -> Chordoma
# MOS003S1        -> Colorectal adenocarcinoma
# MOS171S1        -> Conjunctival melanoma
# MOS076S1        -> Cutaneous Melanoma
# MOS087S1        -> Dedifferentiated liposarcoma
# MOS092S4        -> Dermatofibrosarcoma
# MOS100S1        -> Desmoplastic small round cell tumor
# MOS064S1        -> Esophageal adenocarcinoma
# MOS150S1        -> Extraskeletal Chondrosarcoma
# MOS058S1        -> Hepatocellular carcinoma
# MOS008S1        -> Hurthle cell carcinoma
# MOS104S1        -> Hyalinizing spindle cell sarcoma
# MOS078S1        -> Invasive thymoma
# MOS098S1        -> Leiomyosarcoma
# MOS103S1        -> Liposarcoma
# MOS138T2S1      -> Low grade sarcomatoid process
# MOS010S1        -> Lung adenocarcinoma
# MOS047S1        -> Lung neuroendocrine carcinoma
# MOS083S1        -> Malignant sarcomatoid tumor
# MOS045S1        -> Medullary thyroid carcinoma
# MOS052T2S1      -> Merkel cell carcinoma
# MOS055S1        -> Mesothelioma
# MOS033S1        -> Mucoepidermoid carcinoma
# MOS184S1        -> Nasolacrimal melanoma
# MOS049T2S1      -> Neuroendocrine carcinoma
# MOS053T2S1      -> Neuroendocrine tumor
# MOS099S1        -> Ossifying fibromyxoid tumor
# MOS093S4        -> Osteosarcoma
# MOS059S1        -> Ovarian clear cell carcinoma
# MOS001S1        -> Ovarian clear cell carcinoma
# MOS014S1        -> Ovarian serous carcinoma
# MOS046S1        -> Pancreatic neuroendocrine tumor
# MOS011S1        -> Papillary thyroid carcinoma
# MOS015S1        -> Papillary urothelial carcinoma
# MOS034S1        -> Penile squamous cell carcinoma
# MOS094T2S1      -> Pleomorphic sarcoma
# MOS004S1        -> Rectal squamous cell carcinoma
# MOS042S1        -> Renal cell  carcinoma
# MOS114S1        -> Rhabdomyosarcoma
# MOS163S1        -> Sinonasal melanoma
# MOS090S1        -> Spindle Cell Sarcoma
# MOS085S1        -> Spindle cell malignant neoplasm
# MOS082S1        -> Spindle cell neoplasm
# MOS132S1        -> Spindle cell sarcoma
# MOS097S1        -> Synovial Sarcoma
# MOS143S1        -> Synovial sarcoma
# MOS088S1        -> Unclassified small round cell sarcoma
# MOS096S3        -> Undifferentiated pleomorphic sarcoma
# MOS067S1        -> Undifferentiated thyroid carcinoma
# MOS027S1        -> Urothelial carcinoma
# MOS084S1        -> Uterine adenosarcoma
# MOS153S1        -> Uterine carcinosarcoma
# MOS073S1        -> Uveal Melanoma
# MOS160S1        -> Vulvovaginal melanoma
# MOS109S1        -> Well-differentiated liposarcoma
# MOS060S1        -> Well-differentiated papillary mesothelial tumor
#
# ======================================================================
# TOTAL SELECTED: 63 samples
# ======================================================================
#
#
# ORGANIZED BY CATEGORY:
# ======================================================================
#
# Carcinomas - GI:
#   MOS002S1        -> Cholangiocarcinoma
#   MOS003S1        -> Colorectal adenocarcinoma
#   MOS004S1        -> Rectal squamous cell carcinoma
#   MOS030S1        -> Appendiceal adenocarcinoma
#   MOS064S1        -> Esophageal adenocarcinoma
#   MOS058S1        -> Hepatocellular carcinoma
#   MOS061S1        ->  Pancreas solid pseudopapillary neoplasm
#
# Carcinomas - Gynecologic:
#   MOS001S1        -> Ovarian clear cell carcinoma
#   MOS059S1        -> Ovarian clear cell carcinoma
#   MOS014S1        -> Ovarian serous carcinoma
#   MOS048T2S1      -> Cervical neuroendocrine carcinoma
#   MOS084S1        -> Uterine adenosarcoma
#   MOS153S1        -> Uterine carcinosarcoma
#
# Carcinomas - Urologic:
#   MOS015S1        -> Papillary urothelial carcinoma
#   MOS027S1        -> Urothelial carcinoma
#   MOS042S1        -> Renal cell  carcinoma
#   MOS034S1        -> Penile squamous cell carcinoma
#
# Carcinomas - Thyroid:
#   MOS011S1        -> Papillary thyroid carcinoma
#   MOS045S1        -> Medullary thyroid carcinoma
#   MOS067S1        -> Undifferentiated thyroid carcinoma
#   MOS008S1        -> Hurthle cell carcinoma
#
# Neuroendocrine Tumors:
#   MOS046S1        -> Pancreatic neuroendocrine tumor
#   MOS047S1        -> Lung neuroendocrine carcinoma
#   MOS049T2S1      -> Neuroendocrine carcinoma
#   MOS053T2S1      -> Neuroendocrine tumor
#   MOS052T2S1      -> Merkel cell carcinoma
#
# Lung:
#   MOS010S1        -> Lung adenocarcinoma
#
# Mesothelioma:
#   MOS055S1        -> Mesothelioma
#   MOS060S1        -> Well-differentiated papillary mesothelial tumor
#
# Other Carcinomas:
#   MOS033S1        -> Mucoepidermoid carcinoma
#   MOS078S1        -> Invasive thymoma
#
# Melanomas:
#   MOS070S1        -> Anorectal melanoma
#   MOS160S1        -> Vulvovaginal melanoma
#   MOS163S1        -> Sinonasal melanoma
#   MOS073S1        -> Uveal Melanoma
#   MOS076S1        -> Cutaneous Melanoma
#   MOS171S1        -> Conjunctival melanoma
#   MOS184S1        -> Nasolacrimal melanoma
#
# Sarcomas - Liposarcoma:
#   MOS087S1        -> Dedifferentiated liposarcoma
#   MOS109S1        -> Well-differentiated liposarcoma
#   MOS103S1        -> Liposarcoma
#
# Sarcomas - Leiomyosarcoma:
#   MOS098S1        -> Leiomyosarcoma
#
# Sarcomas - Bone/Cartilage:
#   MOS086S1        -> Chondrosarcoma
#   MOS093S4        -> Osteosarcoma
#   MOS150S1        -> Extraskeletal Chondrosarcoma
#   MOS158S1        -> Chordoma
#
# Sarcomas - Synovial:
#   MOS097S1        -> Synovial Sarcoma
#   MOS143S1        -> Synovial sarcoma
#
# Sarcomas - Pleomorphic/Spindle:
#   MOS096S3        -> Undifferentiated pleomorphic sarcoma
#   MOS094T2S1      -> Pleomorphic sarcoma
#   MOS082S1        -> Spindle cell neoplasm
#   MOS085S1        -> Spindle cell malignant neoplasm
#   MOS090S1        -> Spindle Cell Sarcoma
#   MOS132S1        -> Spindle cell sarcoma
#
# Sarcomas - Other:
#   MOS083S1        -> Malignant sarcomatoid tumor
#   MOS088S1        -> Unclassified small round cell sarcoma
#   MOS092S4        -> Dermatofibrosarcoma
#   MOS100S1        -> Desmoplastic small round cell tumor
#   MOS099S1        -> Ossifying fibromyxoid tumor
#   MOS104S1        -> Hyalinizing spindle cell sarcoma
#   MOS114S1        -> Rhabdomyosarcoma
#   MOS118S1        -> Alveolar soft part sarcoma
#   MOS138T2S1      -> Low grade sarcomatoid process

# %%
import pandas as pd
from collections import Counter
import plotly.graph_objects as go

# Your complete data
all_data = {
    'MOS001S1': 'Ovarian clear cell carcinoma ',
    'MOS002S1': 'Cholangiocarcinoma',
    'MOS003S1': 'Colorectal adenocarcinoma',
    'MOS004S1': 'Rectal squamous cell carcinoma',
    'MOS005S1': 'Cholangiocarcinoma',
    'MOS006S1': 'Cholangiocarcinoma',
    'MOS007S1': 'Cholangiocarcinoma',
    'MOS008S1': 'Hurthle cell carcinoma',
    'MOS009S1': 'Cholangiocarcinoma',
    'MOS010S1': 'Lung adenocarcinoma',
    'MOS011S1': 'Papillary thyroid carcinoma',
    'MOS012S1': 'Colorectal adenocarcinoma',
    'MOS014S1': 'Ovarian serous carcinoma',
    'MOS015S1': 'Papillary urothelial carcinoma',
    'MOS016S1': 'Papillary urothelial carcinoma',
    'MOS017S1': 'Papillary urothelial carcinoma',
    'MOS018S1': 'Papillary urothelial carcinoma',
    'MOS019S1': 'Papillary urothelial carcinoma',
    'MOS020S1': 'Papillary urothelial carcinoma',
    'MOS021S1': 'Papillary urothelial carcinoma',
    'MOS022S1': 'Papillary urothelial carcinoma',
    'MOS023S1': 'Papillary urothelial carcinoma',
    'MOS024S1': 'Papillary urothelial carcinoma',
    'MOS025S1': 'Papillary urothelial carcinoma',
    'MOS026S1': 'Papillary urothelial carcinoma',
    'MOS027S1': 'Urothelial carcinoma',
    'MOS028S1': 'Papillary urothelial carcinoma',
    'MOS029S1': 'Papillary urothelial carcinoma',
    'MOS030S1': 'Appendiceal adenocarcinoma',
    'MOS031S1': 'Rectal squamous cell carcinoma',
    'MOS032S1': 'Cholangiocarcinoma',
    'MOS033S1': 'Mucoepidermoid carcinoma',
    'MOS034S1': 'Penile squamous cell carcinoma',
    'MOS035S1': 'Papillary urothelial carcinoma',
    'MOS036S1': 'Penile squamous cell carcinoma',
    'MOS037S1': 'Papillary urothelial carcinoma',
    'MOS038S1': 'Papillary urothelial carcinoma',
    'MOS039S1': 'Papillary urothelial carcinoma',
    'MOS040S1': 'Papillary urothelial carcinoma',
    'MOS041S1': 'Urothelial carcinoma',
    'MOS042S1': 'Renal cell  carcinoma',
    'MOS043S1': 'Papillary urothelial carcinoma',
    'MOS044S1': 'Papillary urothelial carcinoma',
    'MOS045S1': 'Medullary thyroid carcinoma',
    'MOS046S1': 'Pancreatic neuroendocrine tumor',
    'MOS047S1': 'Lung neuroendocrine carcinoma',
    'MOS048T2S1': 'Cervical neuroendocrine carcinoma',
    'MOS049T2S1': 'Neuroendocrine carcinoma',
    'MOS050T2S1': 'Pancreatic neuroendocrine tumor',
    'MOS051T2S1': 'Pancreatic neuroendocrine tumor',
    'MOS052T2S1': 'Merkel cell carcinoma',
    'MOS053T2S1': 'Neuroendocrine tumor',
    'MOS054T2S1': 'Neuroendocrine tumor',
    'MOS055S1': 'Mesothelioma',
    'MOS056S1': 'Mesothelioma',
    'MOS057S1': 'Mesothelioma',
    'MOS058S1': 'Hepatocellular carcinoma',
    'MOS059S1': 'Ovarian clear cell carcinoma',
    'MOS060S1': 'Well-differentiated papillary mesothelial tumor',
    'MOS061S1': ' Pancreas solid pseudopapillary neoplasm',
    'MOS062S1': 'Colorectal adenocarcinoma',
    'MOS063S1': 'Mucoepidermoid carcinoma',
    'MOS064S1': 'Esophageal adenocarcinoma',
    'MOS065S1': 'Esophageal adenocarcinoma',
    'MOS066S1': 'Papillary urothelial carcinoma',
    'MOS067S1': 'Undifferentiated thyroid carcinoma',
    'MOS068S1': 'Papillary urothelial carcinoma',
    'MOS069S1': 'Papillary urothelial carcinoma',
    'MOS070S1': 'Anorectal melanoma',
    'MOS071S1': 'Anorectal melanoma',
    'MOS072S1': 'Anorectal melanoma',
    'MOS073S1': 'Uveal Melanoma',
    'MOS074S1': 'Uveal Melanoma',
    'MOS075S1': 'Uveal Melanoma',
    'MOS076S1': 'Cutaneous Melanoma',
    'MOS077S1': 'Colorectal adenocarcinoma',
    'MOS078S1': 'Invasive thymoma',
    'MOS079S1': 'Papillary urothelial carcinoma',
    'MOS080S1': 'Colorectal adenocarcinoma',
    'MOS081S1': 'Neuroendocrine tumor',
    'MOS082S1': 'Spindle cell neoplasm',
    'MOS083S1': 'Malignant sarcomatoid tumor',
    'MOS084S1': 'Uterine adenosarcoma',
    'MOS085S1': 'Spindle cell malignant neoplasm',
    'MOS086S1': 'Chondrosarcoma',
    'MOS087S1': 'Dedifferentiated liposarcoma',
    'MOS087S3': 'Dedifferentiated liposarcoma',
    'MOS088S1': 'Unclassified small round cell sarcoma',
    'MOS089S1': 'Dedifferentiated liposarcoma',
    'MOS089S3': 'Dedifferentiated liposarcoma',
    'MOS090S1': 'Spindle Cell Sarcoma',
    'MOS091T2S1': 'Dedifferentiated liposarcoma',
    'MOS092S4': 'Dermatofibrosarcoma',
    'MOS093S4': 'Osteosarcoma',
    'MOS094T2S1': 'Pleomorphic sarcoma',
    'MOS095S3': 'Dedifferentiated liposarcoma',
    'MOS096S3': 'Undifferentiated pleomorphic sarcoma',
    'MOS096S4': 'Undifferentiated pleomorphic sarcoma',
    'MOS097S1': 'Synovial Sarcoma',
    'MOS098S1': 'Leiomyosarcoma',
    'MOS099S1': 'Ossifying fibromyxoid tumor',
    'MOS100S1': 'Desmoplastic small round cell tumor',
    'MOS100S3': 'Desmoplastic small round cell tumor',
    'MOS101S1': 'Leiomyosarcoma',
    'MOS101S3': 'Leiomyosarcoma',
    'MOS102S1': 'Leiomyosarcoma',
    'MOS103S1': 'Liposarcoma',
    'MOS104S1': 'Hyalinizing spindle cell sarcoma',
    'MOS105S1': 'Synovial Sarcoma',
    'MOS106S1': 'Leiomyosarcoma',
    'MOS107S1': 'Undifferentiated pleomorphic sarcoma',
    'MOS108S1': 'Spindle cell malignant neoplasm',
    'MOS109S1': 'Well-differentiated liposarcoma',
    'MOS110S1': 'Pleomorphic sarcoma',
    'MOS111S1': 'Dedifferentiated liposarcoma',
    'MOS111S2': 'Dedifferentiated liposarcoma',
    'MOS112S1': 'Well-differentiated liposarcoma',
    'MOS113S1': 'Dedifferentiated liposarcoma',
    'MOS114S1': 'Rhabdomyosarcoma',
    'MOS115S1': 'Chondrosarcoma',
    'MOS116S1': 'Well-differentiated liposarcoma',
    'MOS117S1': 'Liposarcoma',
    'MOS118S1': 'Alveolar soft part sarcoma',
    'MOS119S1': 'Leiomyosarcoma',
    'MOS120S1': 'Leiomyosarcoma',
    'MOS121S1': 'Chondrosarcoma',
    'MOS122S1': 'Leiomyosarcoma',
    'MOS123S1': 'Synovial Sarcoma',
    'MOS124S1': 'Undifferentiated pleomorphic sarcoma',
    'MOS125S1': 'Undifferentiated pleomorphic sarcoma',
    'MOS126T2S1': 'Synovial Sarcoma',
    'MOS127S1': 'Dedifferentiated liposarcoma',
    'MOS128S1': 'Synovial Sarcoma',
    'MOS129S1': 'Well-differentiated liposarcoma',
    'MOS130S1': 'Chondrosarcoma',
    'MOS131S1': 'Well-differentiated liposarcoma',
    'MOS132S1': 'Spindle cell sarcoma',
    'MOS133S1': 'Liposarcoma',
    'MOS134S1': 'Liposarcoma',
    'MOS135S1': 'Chondrosarcoma',
    'MOS136S1': 'Chondrosarcoma',
    'MOS137S1': 'Undifferentiated pleomorphic sarcoma',
    'MOS138T2S1': 'Low grade sarcomatoid process',
    'MOS139S1': 'Spindle cell sarcoma',
    'MOS140S1': 'Leiomyosarcoma',
    'MOS141S1': 'Leiomyosarcoma',
    'MOS142S1': 'Leiomyosarcoma',
    'MOS143S1': 'Synovial sarcoma',
    'MOS144S1': 'Synovial sarcoma',
    'MOS145S1': 'Leiomyosarcoma',
    'MOS146S1': 'Well-differentiated liposarcoma',
    'MOS147S1': 'Liposarcoma',
    'MOS148S1': 'Liposarcoma',
    'MOS149S1': 'Well-differentiated liposarcoma',
    'MOS150S1': 'Extraskeletal Chondrosarcoma',
    'MOS151S1': 'Synovial Sarcoma',
    'MOS152S1': 'Spindle cell neoplasm',
    'MOS153S1': 'Uterine carcinosarcoma',
    'MOS154S1': 'Uterine adenosarcoma',
    'MOS155S1': 'Chondrosarcoma',
    'MOS156S1': 'Chondrosarcoma',
    'MOS157S1': 'Leiomyosarcoma',
    'MOS158S1': 'Chordoma',
    'MOS159T2S1': 'Leiomyosarcoma',
    'MOS160S1': 'Vulvovaginal melanoma',
    'MOS161S1': 'Vulvovaginal melanoma',
    'MOS162S1': 'Vulvovaginal melanoma',
    'MOS163S1': 'Sinonasal melanoma',
    'MOS165S1': 'Sinonasal melanoma',
    'MOS166S1': 'Vulvovaginal melanoma',
    'MOS167S1': 'Sinonasal melanoma',
    'MOS168S1': 'Anorectal melanoma',
    'MOS169S1': 'Anorectal melanoma',
    'MOS170S1': 'Anorectal melanoma',
    'MOS171S1': 'Conjunctival melanoma',
    'MOS172S1': 'Anorectal melanoma',
    'MOS173S1': 'Anorectal melanoma',
    'MOS174S1': 'Anorectal melanoma',
    'MOS175S1': 'Anorectal melanoma',
    'MOS176S1': 'Vulvovaginal melanoma',
    'MOS177S1': 'Sinonasal melanoma',
    'MOS178S1': 'Anorectal melanoma',
    'MOS179S1': 'Sinonasal melanoma',
    'MOS180S1': 'Sinonasal melanoma',
    'MOS181S1': 'Vulvovaginal melanoma',
    'MOS182S1': 'Vulvovaginal melanoma',
    'MOS183S3': 'Anorectal melanoma',
    'MOS184S1': 'Nasolacrimal melanoma',
    'MOS185S1': 'Anorectal melanoma',
    'MOS186S2': 'Anorectal melanoma',
    'MOS187S2': 'Sinonasal melanoma',
    'MOS188S1': 'Anorectal melanoma',
    'MOS189S1': 'Sinonasal melanoma',
    'MOS190S1': 'Vulvovaginal melanoma',
}

# Count cancer types
cancer_counts = Counter(all_data.values())

# Define categories
categories = {
    'Carcinomas': {
        'GI Tract': ['Cholangiocarcinoma', 'Colorectal adenocarcinoma', 'Rectal squamous cell carcinoma', 
                     'Appendiceal adenocarcinoma', 'Esophageal adenocarcinoma', 'Hepatocellular carcinoma',
                     ' Pancreas solid pseudopapillary neoplasm'],
        'Gynecologic': ['Ovarian clear cell carcinoma ', 'Ovarian clear cell carcinoma', 'Ovarian serous carcinoma',
                       'Cervical neuroendocrine carcinoma'],
        'Urologic': ['Papillary urothelial carcinoma', 'Urothelial carcinoma', 'Renal cell  carcinoma',
                    'Penile squamous cell carcinoma'],
        'Thyroid': ['Papillary thyroid carcinoma', 'Medullary thyroid carcinoma', 'Undifferentiated thyroid carcinoma',
                   'Hurthle cell carcinoma'],
        'Lung': ['Lung adenocarcinoma'],
        'Other': ['Mucoepidermoid carcinoma', 'Invasive thymoma']
    },
    'Neuroendocrine': {
        'Neuroendocrine': ['Pancreatic neuroendocrine tumor', 'Lung neuroendocrine carcinoma', 
                          'Neuroendocrine carcinoma', 'Neuroendocrine tumor', 'Merkel cell carcinoma']
    },
    'Mesothelioma': {
        'Mesothelioma': ['Mesothelioma', 'Well-differentiated papillary mesothelial tumor']
    },
    'Melanomas': {
        'Mucosal': ['Anorectal melanoma', 'Vulvovaginal melanoma', 'Sinonasal melanoma', 
                   'Conjunctival melanoma', 'Nasolacrimal melanoma'],
        'Ocular': ['Uveal Melanoma'],
        'Cutaneous': ['Cutaneous Melanoma']
    },
    'Sarcomas': {
        'Liposarcoma': ['Dedifferentiated liposarcoma', 'Well-differentiated liposarcoma', 'Liposarcoma'],
        'Leiomyosarcoma': ['Leiomyosarcoma'],
        'Bone/Cartilage': ['Chondrosarcoma', 'Osteosarcoma', 'Extraskeletal Chondrosarcoma', 'Chordoma'],
        'Synovial': ['Synovial Sarcoma', 'Synovial sarcoma'],
        'Pleomorphic/Spindle': ['Undifferentiated pleomorphic sarcoma', 'Pleomorphic sarcoma', 'Spindle cell neoplasm',
                                'Spindle cell malignant neoplasm', 'Spindle Cell Sarcoma', 'Spindle cell sarcoma'],
        'Gynecologic': ['Uterine adenosarcoma', 'Uterine carcinosarcoma'],
        'Other': ['Malignant sarcomatoid tumor', 'Unclassified small round cell sarcoma', 'Dermatofibrosarcoma',
                 'Desmoplastic small round cell tumor', 'Ossifying fibromyxoid tumor', 'Hyalinizing spindle cell sarcoma',
                 'Rhabdomyosarcoma', 'Alveolar soft part sarcoma', 'Low grade sarcomatoid process']
    }
}

# Build data for sunburst
labels = []
parents = []
values = []
colors_list = []

# Color palette
main_colors = {
    'Carcinomas': '#E63946',
    'Neuroendocrine': '#F77F00',
    'Mesothelioma': '#FCBF49',
    'Melanomas': '#06D6A0',
    'Sarcomas': '#118AB2'
}

def hex_to_rgb(hex_color):
    hex_color = hex_color.lstrip('#')
    return tuple(int(hex_color[i:i+2], 16)/255 for i in (0, 2, 4))

def rgb_to_hex(rgb):
    return '#{:02x}{:02x}{:02x}'.format(int(rgb[0]*255), int(rgb[1]*255), int(rgb[2]*255))

def lighten_color(hex_color, factor):
    rgb = hex_to_rgb(hex_color)
    lighter = tuple(rgb[i] + (1 - rgb[i]) * factor for i in range(3))
    return rgb_to_hex(lighter)

# Root
labels.append('Rare Cancers')
parents.append('')
values.append(len(all_data))
colors_list.append('#FFFFFF')

# Main categories
for main_cat in categories.keys():
    labels.append(main_cat)
    parents.append('Rare Cancers')
    cat_count = sum(cancer_counts.get(cancer.strip(), 0) 
                   for subcat in categories[main_cat].values() 
                   for cancer in subcat)
    values.append(cat_count)
    colors_list.append(main_colors[main_cat])

# Subcategories and cancers
for main_cat, subcats in categories.items():
    base_color = main_colors[main_cat]
    
    for i, (subcat, cancer_list) in enumerate(subcats.items()):
        subcat_label = f"{subcat}"
        labels.append(subcat_label)
        parents.append(main_cat)
        subcat_count = sum(cancer_counts.get(cancer.strip(), 0) for cancer in cancer_list)
        values.append(subcat_count)
        lighter_color = lighten_color(base_color, 0.3 + (i * 0.05))
        colors_list.append(lighter_color)
        
        for j, cancer in enumerate(cancer_list):
            cancer_clean = cancer.strip()
            if cancer_clean in cancer_counts:
                labels.append(f"{cancer_clean}")
                parents.append(subcat_label)
                values.append(cancer_counts[cancer_clean])
                even_lighter = lighten_color(base_color, 0.5 + (j * 0.02))
                colors_list.append(even_lighter)

# Create the sunburst chart
fig = go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=values,
    marker=dict(
        colors=colors_list,
        line=dict(color='white', width=2)
    ),
    branchvalues='total',
    hovertemplate='<b>%{label}</b><br>Cases: %{value}<extra></extra>'
))

fig.update_layout(
    title={
        'text': 'Distribution of 63 Distinct Rare Cancer Types<br><sub>194 Cases Across Major Cancer Categories</sub>',
        'x': 0.5,
        'xanchor': 'center'
    },
    width=1000,
    height=1000,
    margin=dict(t=100, l=0, r=0, b=0),
    paper_bgcolor='white',
    font=dict(size=12, family='Arial, sans-serif')
)

# Display the chart
fig.show()

print("Sunburst chart displayed successfully!")
# Out:
#   Cell In[19], line 9
#     padding: 20px;
#               ^
# SyntaxError: invalid decimal literal
