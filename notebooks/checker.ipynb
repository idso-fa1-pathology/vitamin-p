# %%
import tensorflow as tf
import numpy as np

import os
import sys
# Add the current directory and its parent to the Python path
current_dir = os.path.dirname(os.path.abspath("__file__"))
parent_dir = os.path.dirname(current_dir)
sys.path.extend([current_dir, parent_dir])

from src.models.expert_he import create_he_expert
from src.models.vit import create_vit_model  # Make sure this import works
# Create dummy data
batch_size = 16
input_shape = (256, 256, 3)
num_classes = {'tc_branch': 19, 'nt_branch': 6}

dummy_input = np.random.rand(batch_size, *input_shape).astype(np.float32)

# Create model
model, encoder = create_he_expert(input_shape, num_classes)

# Compile model (with dummy loss and optimizer)
model.compile(optimizer='adam', loss='mse')

# Print model summary
model.summary()

# Try a forward pass
try:
    outputs = model(dummy_input)
    print("\nForward pass successful!")
    print("Output shapes:")
    for i, name in enumerate(['np_branch', 'hv_branch', 'nt_branch', 'tc_branch']):
        print(f"{name}: {outputs[i].shape}")
except Exception as e:
    print(f"Error during forward pass: {str(e)}")

# Check if shapes match expected output
expected_shapes = [
    (batch_size, 256, 256, 1),  # np_branch
    (batch_size, 256, 256, 2),  # hv_branch
    (batch_size, 256, 256, num_classes['nt_branch']),  # nt_branch
    (batch_size, num_classes['tc_branch'])  # tc_branch
]

all_shapes_correct = True
for i, (output, expected_shape) in enumerate(zip(outputs, expected_shapes)):
    if output.shape != expected_shape:
        print(f"Shape mismatch in branch {i}: Expected {expected_shape}, got {output.shape}")
        all_shapes_correct = False

if all_shapes_correct:
    print("\nAll output shapes are correct!")
else:
    print("\nSome output shapes are incorrect. Please check the model architecture.")
# Out:
# Model output shapes:
# NP branch: (None, 256, 256, 1)
# HV branch: (None, 256, 256, 2)
# NT branch: (None, 256, 256, 6)
# TC branch: (None, 19)
# Model: "model_22"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_16 (InputLayer)       [(None, 256, 256, 3)]        0         []
#
#  model_21 (Functional)       (None, 256, 64)              735488    ['input_16[0][0]']
#
#  dense_150 (Dense)           (None, 256, 65536)           4259840   ['model_21[0][0]']
#
#  reshape_15 (Reshape)        (None, 256, 256, 256)        0         ['dense_150[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 256, 256, 256)        590080    ['reshape_15[0][0]']
#
#  batch_normalization_84 (Ba  (None, 256, 256, 256)        1024      ['conv2d_113[0][0]']
#  tchNormalization)
#
#  conv2d_114 (Conv2D)         (None, 256, 256, 128)        295040    ['batch_normalization_84[0][0]
#                                                                     ']
#
#  batch_normalization_85 (Ba  (None, 256, 256, 128)        512       ['conv2d_114[0][0]']
#  tchNormalization)
#
#  conv2d_115 (Conv2D)         (None, 256, 256, 64)         73792     ['batch_normalization_85[0][0]
#                                                                     ']
#
#  batch_normalization_86 (Ba  (None, 256, 256, 64)         256       ['conv2d_115[0][0]']
#  tchNormalization)
#
#  conv2d_116 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_120 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_124 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_86[0][0]
#                                                                     ']
#
#  batch_normalization_87 (Ba  (None, 256, 256, 64)         256       ['conv2d_116[0][0]']
#  tchNormalization)
#
#  batch_normalization_90 (Ba  (None, 256, 256, 64)         256       ['conv2d_120[0][0]']
#  tchNormalization)
#
#  batch_normalization_93 (Ba  (None, 256, 256, 64)         256       ['conv2d_124[0][0]']
#  tchNormalization)
#
#  conv2d_117 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_87[0][0]
#                                                                     ']
#
#  conv2d_121 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_125 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_93[0][0]
#                                                                     ']
#
#  batch_normalization_88 (Ba  (None, 256, 256, 64)         256       ['conv2d_117[0][0]']
#  tchNormalization)
#
#  batch_normalization_91 (Ba  (None, 256, 256, 64)         256       ['conv2d_121[0][0]']
#  tchNormalization)
#
#  batch_normalization_94 (Ba  (None, 256, 256, 64)         256       ['conv2d_125[0][0]']
#  tchNormalization)
#
#  conv2d_118 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_88[0][0]
#                                                                     ']
#
#  conv2d_122 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_91[0][0]
#                                                                     ']
#
#  conv2d_126 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_94[0][0]
#                                                                     ']
#
#  batch_normalization_89 (Ba  (None, 256, 256, 64)         256       ['conv2d_118[0][0]']
#  tchNormalization)
#
#  batch_normalization_92 (Ba  (None, 256, 256, 64)         256       ['conv2d_122[0][0]']
#  tchNormalization)
#
#  batch_normalization_95 (Ba  (None, 256, 256, 64)         256       ['conv2d_126[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_7  (None, 64)                   0         ['batch_normalization_86[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  conv2d_119 (Conv2D)         (None, 256, 256, 64)         4160      ['batch_normalization_89[0][0]
#                                                                     ']
#
#  conv2d_123 (Conv2D)         (None, 256, 256, 64)         4160      ['batch_normalization_92[0][0]
#                                                                     ']
#
#  conv2d_127 (Conv2D)         (None, 256, 256, 64)         4160      ['batch_normalization_95[0][0]
#                                                                     ']
#
#  dense_151 (Dense)           (None, 256)                  16640     ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  add_21 (Add)                (None, 256, 256, 64)         0         ['conv2d_119[0][0]',
#                                                                      'batch_normalization_86[0][0]
#                                                                     ']
#
#  add_22 (Add)                (None, 256, 256, 64)         0         ['conv2d_123[0][0]',
#                                                                      'batch_normalization_86[0][0]
#                                                                     ']
#
#  add_23 (Add)                (None, 256, 256, 64)         0         ['conv2d_127[0][0]',
#                                                                      'batch_normalization_86[0][0]
#                                                                     ']
#
#  dropout_71 (Dropout)        (None, 256)                  0         ['dense_151[0][0]']
#
#  np_branch (Conv2D)          (None, 256, 256, 1)          65        ['add_21[0][0]']
#
#  hv_branch (Conv2D)          (None, 256, 256, 2)          130       ['add_22[0][0]']
#
#  nt_branch (Conv2D)          (None, 256, 256, 6)          390       ['add_23[0][0]']
#
#  tc_branch (Dense)           (None, 19)                   4883      ['dropout_71[0][0]']
#
# ==================================================================================================
# Total params: 6325276 (24.13 MB)
# Trainable params: 6323228 (24.12 MB)
# Non-trainable params: 2048 (8.00 KB)
# __________________________________________________________________________________________________
#
# Forward pass successful!
# Output shapes:
# np_branch: (16, 256, 256, 1)
# hv_branch: (16, 256, 256, 2)
# nt_branch: (16, 256, 256, 6)
# tc_branch: (16, 19)
#
# All output shapes are correct!

# %%
import tensorflow as tf
import numpy as np
import os
import sys
from tensorflow.keras import mixed_precision

# Add the current directory and its parent to the Python path
current_dir = os.path.dirname(os.path.abspath("__file__"))
parent_dir = os.path.dirname(current_dir)
sys.path.extend([current_dir, parent_dir])

# Import your model creation functions
from src.models.expert_he import create_he_expert
from src.models.vit import create_vit_model

# Define loss functions here
def weighted_bce(class_weights):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        weights = tf.reduce_sum(tf.cast(class_weights, tf.float32) * y_true, axis=-1)
        return tf.reduce_mean(bce * weights)
    return loss

def weighted_focal_loss(alpha, gamma):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        focal_loss = -alpha * y_true * tf.math.pow(1 - y_pred, gamma) * tf.math.log(y_pred)
        return tf.reduce_mean(tf.reduce_sum(focal_loss, axis=-1))
    return loss

def dice_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    numerator = 2 * tf.reduce_sum(y_true * y_pred)
    denominator = tf.reduce_sum(y_true + y_pred)
    return 1 - numerator / denominator

# Set up mixed precision
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)

# Set up multi-GPU strategy
strategy = tf.distribute.MirroredStrategy()
print(f"Number of devices: {strategy.num_replicas_in_sync}")

# Create dummy data
batch_size = 32
input_shape = (256, 256, 3)
num_classes = {'tc_branch': 19, 'nt_branch': 6}
dummy_input = np.random.rand(batch_size, *input_shape).astype(np.float32)

# Create dummy labels
dummy_np = np.random.randint(0, 2, (batch_size, 256, 256, 1)).astype(np.float32)
dummy_hv = np.random.rand(batch_size, 256, 256, 2).astype(np.float32)
dummy_nt = np.random.randint(0, num_classes['nt_branch'], (batch_size, 256, 256)).astype(np.float32)
dummy_nt = tf.keras.utils.to_categorical(dummy_nt, num_classes['nt_branch'])
dummy_tc = np.random.randint(0, num_classes['tc_branch'], (batch_size,)).astype(np.float32)
dummy_tc = tf.keras.utils.to_categorical(dummy_tc, num_classes['tc_branch'])

dummy_labels = {
    'np_branch': dummy_np,
    'hv_branch': dummy_hv,
    'nt_branch': dummy_nt,
    'tc_branch': dummy_tc
}

with strategy.scope():
    model, encoder = create_he_expert(input_shape, num_classes)
    
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, clipvalue=0.5)
    optimizer = mixed_precision.LossScaleOptimizer(optimizer)

    np_weights = tf.constant([1.0, 1.0], dtype=tf.float32)  # Example weights
    loss_functions = {
        'np_branch': lambda y_true, y_pred: weighted_bce(np_weights)(y_true, y_pred) + dice_loss(y_true, y_pred),
        'hv_branch': tf.keras.losses.MeanSquaredError(),
        'nt_branch': weighted_focal_loss(alpha=0.25, gamma=2.0),
        'tc_branch': tf.keras.losses.CategoricalCrossentropy(from_logits=False)
    }
    loss_weights = {
        'np_branch': 0.90,
        'hv_branch': 1.0,
        'nt_branch': 1.0,
        'tc_branch': 1.0
    }

    model.compile(
        optimizer=optimizer,
        loss=loss_functions,
        loss_weights=loss_weights,
        metrics={
            'np_branch': [tf.keras.metrics.BinaryIoU(target_class_ids=[1], threshold=0.5)],
            'hv_branch': [tf.keras.metrics.MeanAbsoluteError()],
            'nt_branch': [tf.keras.metrics.CategoricalAccuracy()],
            'tc_branch': [tf.keras.metrics.CategoricalAccuracy()]
        }
    )

    # Store loss functions and weights in the model for easy access
    model.loss_functions = loss_functions
    model.loss_weights = loss_weights

# Print model summary
model.summary()

# Try a forward pass
try:
    outputs = model(dummy_input)
    print("\nForward pass successful!")
    print("Output shapes:")
    for i, name in enumerate(['np_branch', 'hv_branch', 'nt_branch', 'tc_branch']):
        print(f"{name}: {outputs[i].shape}")
except Exception as e:
    print(f"Error during forward pass: {str(e)}")

# Check if shapes match expected output
expected_shapes = [
    (batch_size, 256, 256, 1),  # np_branch
    (batch_size, 256, 256, 2),  # hv_branch
    (batch_size, 256, 256, num_classes['nt_branch']),  # nt_branch
    (batch_size, num_classes['tc_branch'])  # tc_branch
]
all_shapes_correct = True
for i, (output, expected_shape) in enumerate(zip(outputs, expected_shapes)):
    if output.shape != expected_shape:
        print(f"Shape mismatch in branch {i}: Expected {expected_shape}, got {output.shape}")
        all_shapes_correct = False
if all_shapes_correct:
    print("\nAll output shapes are correct!")
else:
    print("\nSome output shapes are incorrect. Please check the model architecture.")

@tf.function
def train_step(inputs, labels):
    def step_fn(inputs, labels):
        with tf.GradientTape() as tape:
            predictions = model(inputs, training=True)
            
            # Calculate per-example losses manually
            per_example_losses = []
            for branch in ['np_branch', 'hv_branch', 'nt_branch', 'tc_branch']:
                branch_loss = model.loss_functions[branch](labels[branch], predictions[branch])
                per_example_losses.append(model.loss_weights[branch] * branch_loss)
            
            per_example_loss = tf.add_n(per_example_losses)
            loss = tf.nn.compute_average_loss(per_example_loss, global_batch_size=batch_size)
        
        gradients = tape.gradient(loss, model.trainable_variables)
        model.optimizer.apply_gradients(zip(gradients, model.trainable_variables))
        
        # Update metrics
        for branch in ['np_branch', 'hv_branch', 'nt_branch', 'tc_branch']:
            for metric in model.metrics[branch]:
                metric.update_state(labels[branch], predictions[branch])
        
        return loss

    per_replica_losses = strategy.run(step_fn, args=(inputs, labels))
    return strategy.reduce(tf.distribute.ReduceOp.SUM, per_replica_losses, axis=None)

# Modify the evaluation step as well
@tf.function
def distributed_evaluate_step(inputs, labels):
    def eval_step_fn(inputs, labels):
        predictions = model(inputs, training=False)
        
        # Calculate per-example losses manually
        per_example_losses = []
        for branch in ['np_branch', 'hv_branch', 'nt_branch', 'tc_branch']:
            branch_loss = model.loss_functions[branch](labels[branch], predictions[branch])
            per_example_losses.append(model.loss_weights[branch] * branch_loss)
        
        per_example_loss = tf.add_n(per_example_losses)
        loss = tf.nn.compute_average_loss(per_example_loss, global_batch_size=batch_size)
        
        # Update metrics
        for branch in ['np_branch', 'hv_branch', 'nt_branch', 'tc_branch']:
            for metric in model.metrics[branch]:
                metric.update_state(labels[branch], predictions[branch])
        
        return loss

    per_replica_losses = strategy.run(eval_step_fn, args=(inputs, labels))
    return strategy.reduce(tf.distribute.ReduceOp.SUM, per_replica_losses, axis=None)

# Try a training step
try:
    loss = train_step(dummy_input, dummy_labels)
    print(f"\nTraining step successful! Loss: {loss.numpy()}")
    print("Training metrics:")
    for branch in ['np_branch', 'hv_branch', 'nt_branch', 'tc_branch']:
        for metric in model.metrics[branch]:
            print(f"{branch} - {metric.name}: {metric.result().numpy()}")
except Exception as e:
    print(f"Error during training step: {str(e)}")

# Try evaluation
try:
    eval_loss = distributed_evaluate_step(dummy_input, dummy_labels)
    print("\nEvaluation successful!")
    print(f"Evaluation loss: {eval_loss.numpy()}")
    print("Evaluation metrics:")
    for branch in ['np_branch', 'hv_branch', 'nt_branch', 'tc_branch']:
        for metric in model.metrics[branch]:
            print(f"{branch} - {metric.name}: {metric.result().numpy()}")
except Exception as e:
    print(f"Error during evaluation: {str(e)}")
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Number of devices: 4
# Model output shapes:
# NP branch: (None, 256, 256, 1)
# HV branch: (None, 256, 256, 2)
# NT branch: (None, 256, 256, 6)
# TC branch: (None, 19)
# Model: "model_37"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_26 (InputLayer)       [(None, 256, 256, 3)]        0         []
#
#  model_36 (Functional)       (None, 256, 64)              735488    ['input_26[0][0]']
#
#  dense_245 (Dense)           (None, 256, 65536)           4259840   ['model_36[0][0]']
#
#  reshape_25 (Reshape)        (None, 256, 256, 256)        0         ['dense_245[0][0]']
#
#  conv2d_193 (Conv2D)         (None, 256, 256, 256)        590080    ['reshape_25[0][0]']
#
#  batch_normalization_144 (B  (None, 256, 256, 256)        1024      ['conv2d_193[0][0]']
#  atchNormalization)
#
#  conv2d_194 (Conv2D)         (None, 256, 256, 128)        295040    ['batch_normalization_144[0][0
#                                                                     ]']
#
#  batch_normalization_145 (B  (None, 256, 256, 128)        512       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  conv2d_195 (Conv2D)         (None, 256, 256, 64)         73792     ['batch_normalization_145[0][0
#                                                                     ]']
#
#  batch_normalization_146 (B  (None, 256, 256, 64)         256       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  conv2d_196 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_146[0][0
#                                                                     ]']
#
#  conv2d_200 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_146[0][0
#                                                                     ]']
#
#  conv2d_204 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_146[0][0
#                                                                     ]']
#
#  batch_normalization_147 (B  (None, 256, 256, 64)         256       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  batch_normalization_150 (B  (None, 256, 256, 64)         256       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  batch_normalization_153 (B  (None, 256, 256, 64)         256       ['conv2d_204[0][0]']
#  atchNormalization)
#
#  conv2d_197 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_147[0][0
#                                                                     ]']
#
#  conv2d_201 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_150[0][0
#                                                                     ]']
#
#  conv2d_205 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_153[0][0
#                                                                     ]']
#
#  batch_normalization_148 (B  (None, 256, 256, 64)         256       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  batch_normalization_151 (B  (None, 256, 256, 64)         256       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  batch_normalization_154 (B  (None, 256, 256, 64)         256       ['conv2d_205[0][0]']
#  atchNormalization)
#
#  conv2d_198 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_148[0][0
#                                                                     ]']
#
#  conv2d_202 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_151[0][0
#                                                                     ]']
#
#  conv2d_206 (Conv2D)         (None, 256, 256, 64)         36928     ['batch_normalization_154[0][0
#                                                                     ]']
#
#  batch_normalization_149 (B  (None, 256, 256, 64)         256       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  batch_normalization_152 (B  (None, 256, 256, 64)         256       ['conv2d_202[0][0]']
#  atchNormalization)
#
#  batch_normalization_155 (B  (None, 256, 256, 64)         256       ['conv2d_206[0][0]']
#  atchNormalization)
#
#  global_average_pooling2d_1  (None, 64)                   0         ['batch_normalization_146[0][0
#  2 (GlobalAveragePooling2D)                                         ]']
#
#  conv2d_199 (Conv2D)         (None, 256, 256, 64)         4160      ['batch_normalization_149[0][0
#                                                                     ]']
#
#  conv2d_203 (Conv2D)         (None, 256, 256, 64)         4160      ['batch_normalization_152[0][0
#                                                                     ]']
#
#  conv2d_207 (Conv2D)         (None, 256, 256, 64)         4160      ['batch_normalization_155[0][0
#                                                                     ]']
#
#  dense_246 (Dense)           (None, 256)                  16640     ['global_average_pooling2d_12[
#                                                                     0][0]']
#
#  add_36 (Add)                (None, 256, 256, 64)         0         ['conv2d_199[0][0]',
#                                                                      'batch_normalization_146[0][0
#                                                                     ]']
#
#  add_37 (Add)                (None, 256, 256, 64)         0         ['conv2d_203[0][0]',
#                                                                      'batch_normalization_146[0][0
#                                                                     ]']
#
#  add_38 (Add)                (None, 256, 256, 64)         0         ['conv2d_207[0][0]',
#                                                                      'batch_normalization_146[0][0
#                                                                     ]']
#
#  dropout_116 (Dropout)       (None, 256)                  0         ['dense_246[0][0]']
#
#  np_branch (Conv2D)          (None, 256, 256, 1)          65        ['add_36[0][0]']
#
#  hv_branch (Conv2D)          (None, 256, 256, 2)          130       ['add_37[0][0]']
#
#  nt_branch (Conv2D)          (None, 256, 256, 6)          390       ['add_38[0][0]']
#
#  tc_branch (Dense)           (None, 19)                   4883      ['dropout_116[0][0]']
#
# ==================================================================================================
# Total params: 6325276 (24.13 MB)
# Trainable params: 6323228 (24.12 MB)
# Non-trainable params: 2048 (8.00 KB)
# __________________________________________________________________________________________________
#
# Forward pass successful!
# Output shapes:
# np_branch: (32, 256, 256, 1)
# hv_branch: (32, 256, 256, 2)
# nt_branch: (32, 256, 256, 6)
# tc_branch: (32, 19)
#
# All output shapes are correct!
# INFO:tensorflow:Error reported to Coordinator: list indices must be integers or slices, not str
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/training/coordinator.py", line 293, in stop_on_exception
#     yield
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/distribute/mirrored_run.py", line 387, in run
#     self.main_result = self.main_fn(*self.main_args, **self.main_kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/__autograph_generated_file8vn5dtel.py", line 32, in step_fn
#     ag__.for_stmt(['np_branch', 'hv_branch', 'nt_branch', 'tc_branch'], None, loop_body, get_state, set_state, (), {'iterate_names': 'branch'})
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 449, in for_stmt
#     for_fn(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 500, in _py_for_stmt
#     body(target)
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 466, in protected_body
#     original_body(protected_iter)
#   File "/tmp/__autograph_generated_file8vn5dtel.py", line 28, in loop_body
#     branch_loss = ag__.converted_call(ag__.ld(model).loss_functions[ag__.ld(branch)], (ag__.ld(labels)[ag__.ld(branch)], ag__.ld(predictions)[ag__.ld(branch)]), None, fscope_1)
#                                                                                                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# TypeError: list indices must be integers or slices, not str
# Error during training step: in user code:
#
#     File "/tmp/ipykernel_1357/3160447312.py", line 147, in step_fn  *
#         branch_loss = model.loss_functions[branch](labels[branch], predictions[branch])
#
#     TypeError: list indices must be integers or slices, not str
#
# INFO:tensorflow:Error reported to Coordinator: list indices must be integers or slices, not str
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/training/coordinator.py", line 293, in stop_on_exception
#     yield
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/distribute/mirrored_run.py", line 387, in run
#     self.main_result = self.main_fn(*self.main_args, **self.main_kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/__autograph_generated_filexcudcgsi.py", line 31, in eval_step_fn
#     ag__.for_stmt(['np_branch', 'hv_branch', 'nt_branch', 'tc_branch'], None, loop_body, get_state, set_state, (), {'iterate_names': 'branch'})
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 449, in for_stmt
#     for_fn(iter_, extra_test, body, get_state, set_state, symbol_names, opts)
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 500, in _py_for_stmt
#     body(target)
#   File "/usr/local/lib/python3.11/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 466, in protected_body
#     original_body(protected_iter)
#   File "/tmp/__autograph_generated_filexcudcgsi.py", line 27, in loop_body
#     branch_loss = ag__.converted_call(ag__.ld(model).loss_functions[ag__.ld(branch)], (ag__.ld(labels)[ag__.ld(branch)], ag__.ld(predictions)[ag__.ld(branch)]), None, fscope_1)
#                                                                                                                          ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
# TypeError: list indices must be integers or slices, not str
# Error during evaluation: in user code:
#
#     File "/tmp/ipykernel_1357/3160447312.py", line 175, in eval_step_fn  *
#         branch_loss = model.loss_functions[branch](labels[branch], predictions[branch])
#
#     TypeError: list indices must be integers or slices, not str
