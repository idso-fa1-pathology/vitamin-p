# %%
import tensorflow as tf
import numpy as np

import os
import sys
# Add the current directory and its parent to the Python path
current_dir = os.path.dirname(os.path.abspath("__file__"))
parent_dir = os.path.dirname(current_dir)
sys.path.extend([current_dir, parent_dir])

from src.models.expert_he import create_he_expert
from src.models.vit import create_vit_model  # Make sure this import works
# Create dummy data
batch_size = 2
input_shape = (256, 256, 3)
num_classes = {'tc_branch': 19, 'nt_branch': 6}

dummy_input = np.random.rand(batch_size, *input_shape).astype(np.float32)

# Create model
model, encoder = create_he_expert(input_shape, num_classes)

# Compile model (with dummy loss and optimizer)
model.compile(optimizer='adam', loss='mse')

# Print model summary
model.summary()

# Try a forward pass
try:
    outputs = model(dummy_input)
    print("\nForward pass successful!")
    print("Output shapes:")
    for i, name in enumerate(['np_branch', 'hv_branch', 'nt_branch', 'tc_branch']):
        print(f"{name}: {outputs[i].shape}")
except Exception as e:
    print(f"Error during forward pass: {str(e)}")

# Check if shapes match expected output
expected_shapes = [
    (batch_size, 256, 256, 1),  # np_branch
    (batch_size, 256, 256, 2),  # hv_branch
    (batch_size, 256, 256, num_classes['nt_branch']),  # nt_branch
    (batch_size, num_classes['tc_branch'])  # tc_branch
]

all_shapes_correct = True
for i, (output, expected_shape) in enumerate(zip(outputs, expected_shapes)):
    if output.shape != expected_shape:
        print(f"Shape mismatch in branch {i}: Expected {expected_shape}, got {output.shape}")
        all_shapes_correct = False

if all_shapes_correct:
    print("\nAll output shapes are correct!")
else:
    print("\nSome output shapes are incorrect. Please check the model architecture.")
# Out:
# 2024-08-03 19:52:26.014110: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 9.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2024-08-03 19:52:26.027214: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 9.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2024-08-03 19:52:26.037058: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 9.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2024-08-03 19:52:26.045772: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 9.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2024-08-03 19:52:27.695679: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 9.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2024-08-03 19:52:27.697602: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 9.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2024-08-03 19:52:27.698847: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 9.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2024-08-03 19:52:27.700078: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2348] TensorFlow was not built with CUDA kernel binaries compatible with compute capability 9.0. CUDA kernels will be jit-compiled from PTX, which could take 30 minutes or longer.
# 2024-08-03 19:52:27.743512: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78668 MB memory:  -> device: 0, name: NVIDIA H100 80GB HBM3, pci bus id: 0000:1b:00.0, compute capability: 9.0
# 2024-08-03 19:52:27.745374: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 78668 MB memory:  -> device: 1, name: NVIDIA H100 80GB HBM3, pci bus id: 0000:c3:00.0, compute capability: 9.0
# 2024-08-03 19:52:27.764519: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 78668 MB memory:  -> device: 2, name: NVIDIA H100 80GB HBM3, pci bus id: 0000:d1:00.0, compute capability: 9.0
# 2024-08-03 19:52:27.805537: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 78668 MB memory:  -> device: 3, name: NVIDIA H100 80GB HBM3, pci bus id: 0000:df:00.0, compute capability: 9.0
# Model output shapes:
# NP branch: (None, 256, 256, 1)
# HV branch: (None, 256, 256, 2)
# NT branch: (None, 256, 256, 6)
# TC branch: (None, 19)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  model (Functional)          (None, 256, 64)              735488    ['input_2[0][0]']
#
#  dense_17 (Dense)            (None, 256, 65536)           4259840   ['model[0][0]']
#
#  reshape_1 (Reshape)         (None, 256, 256, 256)        0         ['dense_17[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 256)        590080    ['reshape_1[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 256)        1024      ['conv2d_1[0][0]']
#  Normalization)
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 128)        295040    ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 128)        512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 64)         73792     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 256, 256, 64)         256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 256, 256, 64)         36928     ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 64)         36928     ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_12 (Conv2D)          (None, 256, 256, 64)         36928     ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  batch_normalization_3 (Bat  (None, 256, 256, 64)         256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 256, 256, 64)         256       ['conv2d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 256, 256, 64)         256       ['conv2d_12[0][0]']
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 64)         36928     ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 64)         36928     ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_13 (Conv2D)          (None, 256, 256, 64)         36928     ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 256, 256, 64)         256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 256, 256, 64)         256       ['conv2d_9[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 256, 256, 64)         256       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  conv2d_6 (Conv2D)           (None, 256, 256, 64)         36928     ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 64)         36928     ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_14 (Conv2D)          (None, 256, 256, 64)         36928     ['batch_normalization_10[0][0]
#                                                                     ']
#
#  batch_normalization_5 (Bat  (None, 256, 256, 64)         256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 64)         256       ['conv2d_10[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 256, 256, 64)         256       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d (  (None, 64)                   0         ['batch_normalization_2[0][0]'
#  GlobalAveragePooling2D)                                            ]
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 64)         4160      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_11 (Conv2D)          (None, 256, 256, 64)         4160      ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_15 (Conv2D)          (None, 256, 256, 64)         4160      ['batch_normalization_11[0][0]
#                                                                     ']
#
#  dense_18 (Dense)            (None, 256)                  16640     ['global_average_pooling2d[0][
#                                                                     0]']
#
#  add (Add)                   (None, 256, 256, 64)         0         ['conv2d_7[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 256, 256, 64)         0         ['conv2d_11[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  add_2 (Add)                 (None, 256, 256, 64)         0         ['conv2d_15[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_8 (Dropout)         (None, 256)                  0         ['dense_18[0][0]']
#
#  np_branch (Conv2D)          (None, 256, 256, 1)          65        ['add[0][0]']
#
#  hv_branch (Conv2D)          (None, 256, 256, 2)          130       ['add_1[0][0]']
#
#  nt_branch (Conv2D)          (None, 256, 256, 6)          390       ['add_2[0][0]']
#
#  tc_branch (Dense)           (None, 19)                   4883      ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 6325276 (24.13 MB)
# Trainable params: 6323228 (24.12 MB)
# Non-trainable params: 2048 (8.00 KB)
# __________________________________________________________________________________________________
# 2024-08-03 19:52:35.657534: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# Forward pass successful!
# Output shapes:
# np_branch: (2, 256, 256, 1)
# hv_branch: (2, 256, 256, 2)
# nt_branch: (2, 256, 256, 6)
# tc_branch: (2, 19)
#
# All output shapes are correct!
